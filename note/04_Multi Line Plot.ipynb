# %% [markdown]
# # 04_Multi Line Plot
#
# ---
# ## 結論
# 這是一圖多線的基本程式模板。

# %%
import matplotlib.pyplot as plt

x1 = [1,2,3,4,5]
y1 = [1,2,4,8,16]

x2 = [1,2,3,4,5]
y2 = [1,3,9,13,16]

x3 = [1,2,3,4,5]
y3 = [2,4,6,8,10]

plt.plot(x1, y1, 'ro--', label='students')
plt.plot(x2, y2, 'b^-', label='grades')
plt.plot(x3, y3, 'g-', label='visitors')
plt.legend(loc='best')

plt.title('Your title')
plt.xlabel('Horizontal title')
plt.ylabel('Vertical title')
plt.show()

# %% [markdown]
# ---
# ## 教學開始
# 引入模駔

# %%
import matplotlib.pyplot as plt

# %%
x1 = [1,2,3,4,5]
y1 = [1,2,4,8,16]

x2 = [1,2,3,4,5]
y2 = [1,3,9,13,16]

# %%
plt.plot(x1, y1, 'ro')
plt.plot(x2, y2, 'bo')
plt.show()

# %%
plt.plot(x1, y1, 'ro-')
plt.plot(x2, y2, 'bo-')
plt.show()

# %%
plt.plot(x1, y1, 'ro--')
plt.plot(x2, y2, 'b^-')
plt.show()

# %%
plt.plot(x1, y1, 'ro--')
plt.plot(x2, y2, 'b^-')
plt.title('Your title')
plt.xlabel('Horizontal title')
plt.ylabel('Vertical title')
plt.show()

# %% [markdown]
# ---
# ## 一圖多線就是多個數據點資料集

# %%
x1 = [1,2,3,4,5]
y1 = [1,2,4,8,16]

x2 = [1,2,3,4,5]
y2 = [1,3,9,13,16]

x3 = [1,2,3,4,5]
y3 = [2,4,6,8,10]

# %%
plt.plot(x1, y1, 'ro--')
plt.plot(x2, y2, 'b^-')
plt.plot(x3, y3, 'g-')

plt.title('Your title')
plt.xlabel('Horizontal title')
plt.ylabel('Vertical title')
plt.show()

# %% [markdown]
# ---
# ## 加上label，並顯示legend
#
# - plt.legend(loc='best')
#     - loc: location，可以調整位置很自由。best有一個好處是會挑選做恰當的位置，但如果要畫多圖，可能程式會變很慢，因為要多一個判斷。

# %% [markdown]
# loc : int or string or pair of floats, default: :rc:`legend.loc` ('best' for axes, 'upper right' for figures)
#     The location of the legend. Possible codes are:
#
#         ===============   =============
#         Location String   Location Code
#         ===============   =============
#         'best'            0
#         'upper right'     1
#         'upper left'      2
#         'lower left'      3
#         'lower right'     4
#         'right'           5
#         'center left'     6
#         'center right'    7
#         'lower center'    8
#         'upper center'    9
#         'center'          10
#         ===============   =============
#
#
#     Alternatively can be a 2-tuple giving ``x, y`` of the lower-left
#     corner of the legend in axes coordinates (in which case
#     ``bbox_to_anchor`` will be ignored).
#
#     The 'best' option can be quite slow for plots with large amounts
#     of data. Your plotting speed may benefit from providing a specific
#     location.
#
# > 或者可以是一個2元組，在軸坐標中給出圖例左下角的“x，y`”（在這種情況下，``bbox_to_anchor``將被忽略）。
# >
# > 對於包含大量數據的繪圖，“最佳”選項可能非常慢。 您的繪圖速度可能會受益於提供特定位置。
# ---

# %%
plt.plot(x1, y1, 'ro--', label='line 1')
plt.plot(x2, y2, 'b^-', label='line 2')
plt.plot(x3, y3, 'g-', label='line 3')
plt.legend(loc='best')

plt.title('Your title')
plt.xlabel('Horizontal title')
plt.ylabel('Vertical title')
plt.show()

# %% [markdown]
# - loc = best，會將圖例調整到最好的位置。

# %%
x1 = [5,4,3,2,1]
y1 = [1,2,4,8,16]

x2 = [5,4,3,2,1]
y2 = [1,3,9,13,16]

x3 = [5,4,3,2,1]
y3 = [2,4,6,8,10]

# %%
plt.plot(x1, y1, 'ro--', label='students')
plt.plot(x2, y2, 'b^-', label='grades')
plt.plot(x3, y3, 'g-', label='visitors')
plt.legend(loc='best')

plt.title('Your title')
plt.xlabel('Horizontal title')
plt.ylabel('Vertical title')
plt.show()

# %% [markdown]
# ---
# ## 結論
# 這是一圖多線的基本程式模板。

# %%
import matplotlib.pyplot as plt

x1 = [1,2,3,4,5]
y1 = [1,2,4,8,16]

x2 = [1,2,3,4,5]
y2 = [1,3,9,13,16]

x3 = [1,2,3,4,5]
y3 = [2,4,6,8,10]

plt.plot(x1, y1, 'ro--', label='students')
plt.plot(x2, y2, 'b^-', label='grades')
plt.plot(x3, y3, 'g-', label='visitors')
plt.legend(loc='best')

plt.title('Your title')
plt.xlabel('Horizontal title')
plt.ylabel('Vertical title')
plt.show()
