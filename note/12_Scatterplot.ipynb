# %% [markdown]
# # 12_Scatterplot
#
# ---
# ## 結論
# 這是繪製 scatter plot 的範例程式模板

# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
sns.set_style("darkgrid")

N = 50
x1 = np.random.rand(N)
y1 = np.random.rand(N)
s1 = np.random.rand(N) * 300
x2 = np.random.rand(N)
y2 = np.random.rand(N)
s2 = np.random.rand(N) * 300

plt.scatter(x1, y1,s=s1)
plt.scatter(x2, y2,s=s2)
plt.title('Your title')
plt.xlabel('Horizontal title')
plt.ylabel('Vertical title')
plt.show()

# %% [markdown]
# ---
# ## 教學開始
#
# 引入模組

# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %% [markdown]
# ---
# ## 設定繪圖風格與資料點產生

# %%
plt.rcdefaults()
sns.set_style("darkgrid")

N = 50
x1 = np.random.rand(N) #產生亂數
y1 = np.random.rand(N)
s1 = np.random.rand(N) * 300

x2 = np.random.rand(N)
y2 = np.random.rand(N)
s2 = np.random.rand(N) * 300

# %% [markdown]
# ---
# ## 繪圖與點大小設定
#
# - s : scalar or array_like, shape (n, ), optional
#     - The marker size in points**2.
#     - Default is ``rcParams['lines.markersize'] ** 2``.

# %%
plt.scatter(x1, y1)
plt.scatter(x2, y2)
plt.title('Your title')
plt.xlabel('Horizontal title')
plt.ylabel('Vertical title')
plt.show()

# %%
plt.scatter(x1, y1, s = 10)
plt.scatter(x2, y2, s = 30)
plt.title('Your title')
plt.xlabel('Horizontal title')
plt.ylabel('Vertical title')
plt.show()

# %%
plt.scatter(x1, y1, s=s1)
plt.scatter(x2, y2, s=s2)
plt.title('Your title')
plt.xlabel('Horizontal title')
plt.ylabel('Vertical title')
plt.show()

# %% [markdown]
# ---
# ## 結論
# 這是繪製 scatter plot 的範例程式模板

# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
sns.set_style("darkgrid")

N = 50
x1 = np.random.rand(N)
y1 = np.random.rand(N)
s1 = np.random.rand(N) * 300
x2 = np.random.rand(N)
y2 = np.random.rand(N)
s2 = np.random.rand(N) * 300

plt.scatter(x1, y1,s=s1)
plt.scatter(x2, y2,s=s2)
plt.title('Your title')
plt.xlabel('Horizontal title')
plt.ylabel('Vertical title')
plt.show()
